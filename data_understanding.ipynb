# %% [markdown]
# <a href="https://colab.research.google.com/github/aceballosGitHub/Analisis-Exploratorio/blob/main/data_understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar la librería pandas
import pandas as pd

# Leer el conjunto de datos por medio de la URL proporcionada y asignarlo a la variable "df"
other_path = "https://raw.githubusercontent.com/lvmeninnovations/datasets/main/crispdm/auto.csv"
df = pd.read_csv(other_path, header=None)

# Crear la lista de nombres para el encabezado
headers = ["factor-riesgo","perdida-promedio-anual","fabricante","tipo-combustible","aspiracion", "num-puertas","estilo-carroceria",
         "traccion","ubicacion-motor","distancia-entre-ejes", "longitud","anchura","altura","peso-vacio","tipo-motor",
         "num-cilindros", "tamano-motor","sistema-combustible","calibre","carrera","relacion-compresion","caballos-fuerza",
         "pico-rpm","millas_por_galon_ciudad","millas_por_galon_carretera","precio"]
print("encabezados\n", headers)
# Out:
# encabezados
#  ['factor-riesgo', 'perdida-promedio-anual', 'fabricante', 'tipo-combustible', 'aspiracion', 'num-puertas', 'estilo-carroceria', 'traccion', 'ubicacion-motor', 'distancia-entre-ejes', 'longitud', 'anchura', 'altura', 'peso-vacio', 'tipo-motor', 'num-cilindros', 'tamano-motor', 'sistema-combustible', 'calibre', 'carrera', 'relacion-compresion', 'caballos-fuerza', 'pico-rpm', 'millas_por_galon_ciudad', 'millas_por_galon_carretera', 'precio']

# %%
df.columns = headers
df.head(10)
# Out:
#    factor-riesgo perdida-promedio-anual   fabricante tipo-combustible  \
# 0              3                      ?  alfa-romero              gas
# 1              3                      ?  alfa-romero              gas
# 2              1                      ?  alfa-romero              gas
# 3              2                    164         audi              gas
# 4              2                    164         audi              gas
# 5              2                      ?         audi              gas
# 6              1                    158         audi              gas
# 7              1                      ?         audi              gas
# 8              1                    158         audi              gas
# 9              0                      ?         audi              gas
#
#   aspiracion num-puertas estilo-carroceria traccion ubicacion-motor  \
# 0        std         two       convertible      rwd           front
# 1        std         two       convertible      rwd           front
# 2        std         two         hatchback      rwd           front
# 3        std        four             sedan      fwd           front
# 4        std        four             sedan      4wd           front
# 5        std         two             sedan      fwd           front
# 6        std        four             sedan      fwd           front
# 7        std        four             wagon      fwd           front
# 8      turbo        four             sedan      fwd           front
# 9      turbo         two         hatchback      4wd           front
#
#    distancia-entre-ejes  ...  tamano-motor  sistema-combustible  calibre  \
# 0                  88.6  ...           130                 mpfi     3.47
# 1                  88.6  ...           130                 mpfi     3.47
# 2                  94.5  ...           152                 mpfi     2.68
# 3                  99.8  ...           109                 mpfi     3.19
# 4                  99.4  ...           136                 mpfi     3.19
# 5                  99.8  ...           136                 mpfi     3.19
# 6                 105.8  ...           136                 mpfi     3.19
# 7                 105.8  ...           136                 mpfi     3.19
# 8                 105.8  ...           131                 mpfi     3.13
# 9                  99.5  ...           131                 mpfi     3.13
#
#    carrera relacion-compresion caballos-fuerza  pico-rpm  \
# 0     2.68                 9.0             111      5000
# 1     2.68                 9.0             111      5000
# 2     3.47                 9.0             154      5000
# 3     3.40                10.0             102      5500
# 4     3.40                 8.0             115      5500
# 5     3.40                 8.5             110      5500
# 6     3.40                 8.5             110      5500
# 7     3.40                 8.5             110      5500
# 8     3.40                 8.3             140      5500
# 9     3.40                 7.0             160      5500
#
#   millas_por_galon_ciudad millas_por_galon_carretera precio
# 0                      21                         27  13495
# 1                      21                         27  16500
# 2                      19                         26  16500
# 3                      24                         30  13950
# 4                      18                         22  17450
# 5                      19                         25  15250
# 6                      19                         25  17710
# 7                      19                         25  18920
# 8                      17                         20  23875
# 9                      16                         22      ?
#
# [10 rows x 26 columns]

# %%
# Comprobar el tipo de datos del data frame "df" por medio de .dtypes
print(df.dtypes)
# Out:
# factor-riesgo                   int64
# perdida-promedio-anual         object
# fabricante                     object
# tipo-combustible               object
# aspiracion                     object
# num-puertas                    object
# estilo-carroceria              object
# traccion                       object
# ubicacion-motor                object
# distancia-entre-ejes          float64
# longitud                      float64
# anchura                       float64
# altura                        float64
# peso-vacio                      int64
# tipo-motor                     object
# num-cilindros                  object
# tamano-motor                    int64
# sistema-combustible            object
# calibre                        object
# carrera                        object
# relacion-compresion           float64
# caballos-fuerza                object
# pico-rpm                       object
# millas_por_galon_ciudad         int64
# millas_por_galon_carretera      int64
# precio                         object
# dtype: object

# %%
# Obtener el resumen estadístico de las columnas de tipo numérico
df.describe()
# Out:
#        factor-riesgo  distancia-entre-ejes    longitud     anchura  \
# count     205.000000            205.000000  205.000000  205.000000
# mean        0.834146             98.756585  174.049268   65.907805
# std         1.245307              6.021776   12.337289    2.145204
# min        -2.000000             86.600000  141.100000   60.300000
# 25%         0.000000             94.500000  166.300000   64.100000
# 50%         1.000000             97.000000  173.200000   65.500000
# 75%         2.000000            102.400000  183.100000   66.900000
# max         3.000000            120.900000  208.100000   72.300000
#
#            altura   peso-vacio  tamano-motor  relacion-compresion  \
# count  205.000000   205.000000    205.000000           205.000000
# mean    53.724878  2555.565854    126.907317            10.142537
# std      2.443522   520.680204     41.642693             3.972040
# min     47.800000  1488.000000     61.000000             7.000000
# 25%     52.000000  2145.000000     97.000000             8.600000
# 50%     54.100000  2414.000000    120.000000             9.000000
# 75%     55.500000  2935.000000    141.000000             9.400000
# max     59.800000  4066.000000    326.000000            23.000000
#
#        millas_por_galon_ciudad  millas_por_galon_carretera
# count               205.000000                  205.000000
# mean                 25.219512                   30.751220
# std                   6.542142                    6.886443
# min                  13.000000                   16.000000
# 25%                  19.000000                   25.000000
# 50%                  24.000000                   30.000000
# 75%                  30.000000                   34.000000
# max                  49.000000                   54.000000

# %%
# Obtener el resumen estadístico de todas las columnas de "df"
df.describe(include = "all")
# Out:
#         factor-riesgo perdida-promedio-anual fabricante tipo-combustible  \
# count      205.000000                    205        205              205
# unique            NaN                     52         22                2
# top               NaN                      ?     toyota              gas
# freq              NaN                     41         32              185
# mean         0.834146                    NaN        NaN              NaN
# std          1.245307                    NaN        NaN              NaN
# min         -2.000000                    NaN        NaN              NaN
# 25%          0.000000                    NaN        NaN              NaN
# 50%          1.000000                    NaN        NaN              NaN
# 75%          2.000000                    NaN        NaN              NaN
# max          3.000000                    NaN        NaN              NaN
#
#        aspiracion num-puertas estilo-carroceria traccion ubicacion-motor  \
# count         205         205               205      205             205
# unique          2           3                 5        3               2
# top           std        four             sedan      fwd           front
# freq          168         114                96      120             202
# mean          NaN         NaN               NaN      NaN             NaN
# std           NaN         NaN               NaN      NaN             NaN
# min           NaN         NaN               NaN      NaN             NaN
# 25%           NaN         NaN               NaN      NaN             NaN
# 50%           NaN         NaN               NaN      NaN             NaN
# 75%           NaN         NaN               NaN      NaN             NaN
# max           NaN         NaN               NaN      NaN             NaN
#
#         distancia-entre-ejes  ...  tamano-motor  sistema-combustible  calibre  \
# count             205.000000  ...    205.000000                  205      205
# unique                   NaN  ...           NaN                    8       39
# top                      NaN  ...           NaN                 mpfi     3.62
# freq                     NaN  ...           NaN                   94       23
# mean               98.756585  ...    126.907317                  NaN      NaN
# std                 6.021776  ...     41.642693                  NaN      NaN
# min                86.600000  ...     61.000000                  NaN      NaN
# 25%                94.500000  ...     97.000000                  NaN      NaN
# 50%                97.000000  ...    120.000000                  NaN      NaN
# 75%               102.400000  ...    141.000000                  NaN      NaN
# max               120.900000  ...    326.000000                  NaN      NaN
#
#         carrera relacion-compresion caballos-fuerza  pico-rpm  \
# count       205          205.000000             205       205
# unique       37                 NaN              60        24
# top        3.40                 NaN              68      5500
# freq         20                 NaN              19        37
# mean        NaN           10.142537             NaN       NaN
# std         NaN            3.972040             NaN       NaN
# min         NaN            7.000000             NaN       NaN
# 25%         NaN            8.600000             NaN       NaN
# 50%         NaN            9.000000             NaN       NaN
# 75%         NaN            9.400000             NaN       NaN
# max         NaN           23.000000             NaN       NaN
#
#        millas_por_galon_ciudad millas_por_galon_carretera precio
# count               205.000000                 205.000000    205
# unique                     NaN                        NaN    187
# top                        NaN                        NaN      ?
# freq                       NaN                        NaN      4
# mean                 25.219512                  30.751220    NaN
# std                   6.542142                   6.886443    NaN
# min                  13.000000                  16.000000    NaN
# 25%                  19.000000                  25.000000    NaN
# 50%                  24.000000                  30.000000    NaN
# 75%                  30.000000                  34.000000    NaN
# max                  49.000000                  54.000000    NaN
#
# [11 rows x 26 columns]

# %%
#Ejercicio 1
#Aplique el método .describe() a las columnas 'longitud' y 'relacion-compresion'

#df[['longitud', 'relacion-compresion'] ].describe()
df[['longitud', 'relacion-compresion'] ].describe(include = "all")
# Out:
#          longitud  relacion-compresion
# count  205.000000           205.000000
# mean   174.049268            10.142537
# std     12.337289             3.972040
# min    141.100000             7.000000
# 25%    166.300000             8.600000
# 50%    173.200000             9.000000
# 75%    183.100000             9.400000
# max    208.100000            23.000000

# %%
# Ver la información de "df"
df.info
# Out:
# <bound method DataFrame.info of      factor-riesgo perdida-promedio-anual   fabricante tipo-combustible  \
# 0                3                      ?  alfa-romero              gas
# 1                3                      ?  alfa-romero              gas
# 2                1                      ?  alfa-romero              gas
# 3                2                    164         audi              gas
# 4                2                    164         audi              gas
# ..             ...                    ...          ...              ...
# 200             -1                     95        volvo              gas
# 201             -1                     95        volvo              gas
# 202             -1                     95        volvo              gas
# 203             -1                     95        volvo           diesel
# 204             -1                     95        volvo              gas
#
#     aspiracion num-puertas estilo-carroceria traccion ubicacion-motor  \
# 0          std         two       convertible      rwd           front
# 1          std         two       convertible      rwd           front
# 2          std         two         hatchback      rwd           front
# 3          std        four             sedan      fwd           front
# 4          std        four             sedan      4wd           front
# ..         ...         ...               ...      ...             ...
# 200        std        four             sedan      rwd           front
# 201      turbo        four             sedan      rwd           front
# 202        std        four             sedan      rwd           front
# 203      turbo        four             sedan      rwd           front
# 204      turbo        four             sedan      rwd           front
#
#      distancia-entre-ejes  ...  tamano-motor  sistema-combustible  calibre  \
# 0                    88.6  ...           130                 mpfi     3.47
# 1                    88.6  ...           130                 mpfi     3.47
# 2                    94.5  ...           152                 mpfi     2.68
# 3                    99.8  ...           109                 mpfi     3.19
# 4                    99.4  ...           136                 mpfi     3.19
# ..                    ...  ...           ...                  ...      ...
# 200                 109.1  ...           141                 mpfi     3.78
# 201                 109.1  ...           141                 mpfi     3.78
# 202                 109.1  ...           173                 mpfi     3.58
# 203                 109.1  ...           145                  idi     3.01
# 204                 109.1  ...           141                 mpfi     3.78
#
#      carrera relacion-compresion caballos-fuerza  pico-rpm  \
# 0       2.68                 9.0             111      5000
# 1       2.68                 9.0             111      5000
# 2       3.47                 9.0             154      5000
# 3       3.40                10.0             102      5500
# 4       3.40                 8.0             115      5500
# ..       ...                 ...             ...       ...
# 200     3.15                 9.5             114      5400
# 201     3.15                 8.7             160      5300
# 202     2.87                 8.8             134      5500
# 203     3.40                23.0             106      4800
# 204     3.15                 9.5             114      5400
#
#     millas_por_galon_ciudad millas_por_galon_carretera precio
# 0                        21                         27  13495
# 1                        21                         27  16500
# 2                        19                         26  16500
# 3                        24                         30  13950
# 4                        18                         22  17450
# ..                      ...                        ...    ...
# 200                      23                         28  16845
# 201                      19                         25  19045
# 202                      18                         23  21485
# 203                      26                         27  22470
# 204                      19                         25  22625
#
# [205 rows x 26 columns]>

# %%
# Importar la librería altair
import altair as alt

# %%
# Intanciar un objeto Chart con el dataframe df como parámetro
base = alt.Chart(df)

# Llamar el método mark_circle() para especificar que va a trazar un diagrama de dispersión (scatter plot)
chart = base.mark_circle()

# Especificar el nombre de las columnas:
chart.encode(x='millas_por_galon_carretera', y='tamano-motor')
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_circle().encode(x='millas_por_galon_carretera', y='tamano-motor')
# Out:
# alt.Chart(...)

# %%
#misma gráfica pero con fabricante
alt.Chart(df).mark_circle().encode(x='millas_por_galon_carretera', y='tamano-motor', color='fabricante')
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_circle()\
   .encode(x='millas_por_galon_carretera', y='tamano-motor', color='fabricante', \
           tooltip=['fabricante','tipo-combustible','num-puertas',\
                    'estilo-carroceria','ubicacion-motor']).interactive()
# Out:
# alt.Chart(...)

# %%
#Histograma
alt.Chart(df).mark_bar()\
   .encode(alt.X("precio:Q", bin=True), \
           y='count()')
# Out:
# alt.Chart(...)

# %%
#Ejercicio 2
#Grafique el histograma para el atributo precio agrupando los precios en rangos de 1000
alt.Chart(df).mark_bar()\
   .encode(alt.X("precio:Q", bin=alt.Bin(step=1000)),  # Especificar el tamaño del bin como 1000
       y='count()')
# Out:
# alt.Chart(...)

# %%
#Ejercicio 2.1 + color
#Grafique el histograma para el atributo precio agrupando los precios en rangos de 1000 y detallando el color del fabricante
alt.Chart(df).mark_bar()\
   .encode(alt.X("precio:Q", bin=alt.Bin(step=1000)),  # Especificar el tamaño del bin como 1000
       y='count()', color='fabricante')
# Out:
# alt.Chart(...)

# %%
#Ejercicio 2.2 + color + interactive
#Grafique el histograma para el atributo precio agrupando los precios en rangos de 1000 y detallando el color del fabricante
alt.Chart(df).mark_bar()\
   .encode(alt.X("precio:Q", bin=alt.Bin(step=1000)),  # Especificar el tamaño del bin como 1000
       y='count()', color='fabricante', \
           tooltip=['fabricante','tipo-combustible','num-puertas',\
                    'estilo-carroceria','ubicacion-motor']).interactive()
# Out:
# alt.Chart(...)

# %%
#diagrama de barras para atributos categóricos
alt.Chart(df).mark_bar()\
   .encode(x='num-cilindros',y='count()')
# Out:
# alt.Chart(...)

# %%
#Diagramas de caja (Boxplots)
alt.Chart(df).mark_boxplot().encode(x='num-cilindros:O', y='precio:Q')
# Out:
# alt.Chart(...)

# %%
#Ejercicio 3
#Genere el diagrama de caja con los atributos fabricante y precio utilizando el método mark_boxplot()

alt.Chart(df).mark_boxplot().encode(x='fabricante:O', y='precio:Q')
# Out:
# alt.Chart(...)

# %%
# Obtener la correlación entre variables por medio del coeficiente de correlación de Pearson
correlation = df.corr(method='pearson').reset_index().melt('index')
correlation.columns = ['variable1', 'variable2', 'indice-correlation']

correlation.head()
# Out:
# <ipython-input-21-00dd5681e24d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr(method='pearson').reset_index().melt('index')
#               variable1      variable2  indice-correlation
# 0         factor-riesgo  factor-riesgo            1.000000
# 1  distancia-entre-ejes  factor-riesgo           -0.531954
# 2              longitud  factor-riesgo           -0.357612
# 3               anchura  factor-riesgo           -0.232919
# 4                altura  factor-riesgo           -0.541038

# %%
# Grafica del mapa de calor
chart = alt.Chart(correlation).mark_rect().encode(
    x=alt.X('variable1', title=None),
    y=alt.Y('variable2', title=None),
    # El color de cada casilla dependerá del índice de correlación hallado
    color=alt.Color('indice-correlation'),
).properties(
    # Establecemos el tamaño del gráfico
    width=alt.Step(40),
    height=alt.Step(40)
)

# Personalizamos el tamaño del texto de las casillas internas
chart += chart.mark_text(size=10).encode(
    # Establecemos el formato de la barra de temperatura
    text=alt.Text('indice-correlation', format=".2f"),
    color=alt.condition(
        "datum.correlation > 0.5",
        alt.value('white'),
        alt.value('black')
    )
)

# Desplegamos el gráfico
chart
# Out:
# alt.LayerChart(...)

# %%
#Ejercicio 4
#Genere el mapa de calor utilizando el coeficiente de correlación de Spearman. Establezca el tamaño del gráfico en 60 x 60 y un tamaño de letra de 20 para las casillas

# Grafica del mapa de calor


correlation = df.corr(method='spearman').reset_index().melt('index')
correlation.columns = ['variable1', 'variable2', 'indice-correlation']

correlation.head()

chart = alt.Chart(correlation).mark_rect().encode(
    x=alt.X('variable1', title=None),
    y=alt.Y('variable2', title=None),
    # El color de cada casilla dependerá del índice de correlación hallado
    color=alt.Color('indice-correlation'),
).properties(
    # Establecemos el tamaño del gráfico
    width=alt.Step(60),
    height=alt.Step(60)
)

# Personalizamos el tamaño del texto de las casillas internas
chart += chart.mark_text(size=20).encode(
    # Establecemos el formato de la barra de temperatura
    text=alt.Text('indice-correlation', format=".2f"),
    color=alt.condition(
        "datum.correlation > 0.5",
        alt.value('white'),
        alt.value('black')
    )
)

# Desplegamos el gráfico
chart
# Out:
# <ipython-input-23-b409460cc054>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr(method='spearman').reset_index().melt('index')
# alt.LayerChart(...)
